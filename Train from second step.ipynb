# %% [markdown]
# ### - import updated dataset
# ### - import policy from pickle
# ### - create new algorithm with as policy the imported policy
# ### - algorithm.step
# ### - save pickle for new algorithm, new policy and new action dispatcher

# %%
# %load_ext autoreload
# %aimport os, pandas, numpy, pickle
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pandas as pd
ds = pd.read_csv('./trajectory/dataset.csv')
rt = pd.read_csv('./trajectory/ref_traj.csv')

# %%
import pandas as pd
import sys
import os
import pickle
import argparse
from trlib.policies.valuebased import EpsilonGreedy, Softmax
from trlib.policies.qfunction import ZeroQ
from sklearn.ensemble.forest import ExtraTreesRegressor
from trlib.algorithms.reinforcement.fqi_driver import FQIDriver, DoubleFQIDriver
from trlib.environments.trackEnv import TrackEnv
from trlib.utilities.ActionDispatcher import *
from fqi.dataset_preprocessing import *
from fqi.fqi_evaluate import run_evaluation
"""from fqi.et_tuning import run_tuning"""
from fqi.utils import *
from fqi.reward_function import *
from fqi.sars_creator import *
sys.setrecursionlimit(3000)

ref_df = pd.read_csv('./trajectory/ref_traj.csv')
data_df = pd.read_csv('./trajectory/dataset.csv')

print("There are", data_df.tail(1)['NLap'].values, "laps")
# Out:
# There are [169.] laps

# %%
def run_experiment(track_file_name, rt_file_name, data_path, max_iterations, output_path, n_throttle,
               n_brake, n_steer, n_jobs, output_name, reward_function, delta_t,
               filter_actions, ad_type, tuning, kdt_norm, kdt_param, filt_a_outliers, double_fqi, evaluation):


    # instantiate Reward Function and build SARS
    if reward_function == 'speed':
        print('SPEED REWARD FUNCTION')
        reward_function = Speed_projection(ref_df)
    elif reward_function == 'spatial':
        print('SPATIAL REWARD FUNCTION')
        reward_function = Spatial_projection(ref_df)
    elif reward_function == 'temporal':
        print('TEMPORAL REWARD FUNCTION')
        reward_function = Temporal_projection(ref_df)
    sars_data = to_SARS(data_df, reward_function)
    
    print('SARS ready')
    nmin = 5

    # Create environment
    state_dim = len(state_cols)
    action_dim = len(action_cols)
    mdp = TrackEnv(state_dim, action_dim, 0.99999, 'continuous')

    # Parameters of ET regressor
    regressor_params = {'n_estimators': 100,
                        'criterion': 'mse',
                        'min_samples_split': 2,
                        'min_samples_leaf': nmin,
                        'n_jobs': n_jobs,
                        'random_state': 42}
    regressor = ExtraTreesRegressor

    if ad_type == 'fkdt':
        action_dispatcher = FixedKDTActionDispatcher
        alg_actions = sars_data[action_cols].values

    elif ad_type == 'rkdt':
        action_dispatcher = RadialKDTActionDispatcher
        alg_actions = sars_data[action_cols].values

    elif ad_type == 'discrete':
        action_dispatcher = ConstantActionDispatcher
        actions, sub_actions = create_action_combinations(sars_data, n_throttle, n_brake, n_steer, filter_actions)
        alg_actions = sub_actions
    else:
        action_dispatcher = None
        alg_actions = None

    # import policy
    algorithm_name = output_name + '.pkl'
    policy_name = 'policy_' + algorithm_name
    with open(output_path + '/' + policy_name, 'rb') as pol:
        print('loading policy')
        pi = pickle.load(pol)
        print('pi:', pi)

    # Define the order of the columns to pass to the algorithm
    # state_prime_cols: colonne dello stato successivo
    cols = ['t'] + state_cols + action_cols + ['r'] + state_prime_cols + ['absorbing']
    # Define the masks used by the action dispatcher
    state_mask = [i for i, s in enumerate(state_cols) if s in knn_state_cols]
    data_mask = [i for i, c in enumerate(cols) if c in knn_state_cols]

    if double_fqi:
        fqi = DoubleFQIDriver
    else:
        fqi = FQIDriver

    algorithm = fqi(mdp=mdp,
                    policy=pi,
                    actions=alg_actions,
                    max_iterations=max_iterations,
                    regressor_type=regressor,
                    data=sars_data[cols].values,
                    action_dispatcher=action_dispatcher,
                    state_mask=state_mask,
                    data_mask=data_mask,
                    s_norm=kdt_norm,
                    filter_a_outliers=filt_a_outliers,
                    ad_n_jobs=n_jobs,
                    ad_param=kdt_param,
                    verbose=True,
                    **regressor_params)

    result = algorithm.step()
    

    # save algorithm object
    algorithm_name = output_name + '.pkl'
    with open(output_path + '/' + algorithm_name, 'wb') as output:
        pickle.dump(algorithm, output, pickle.HIGHEST_PROTOCOL)
    print('Saved algorithm object')
    
    # save policy object
    policy_name = 'policy_' + algorithm_name
    with open(output_path + '/' + policy_name, 'wb') as output:
        pickle.dump(algorithm._policy, output, pickle.HIGHEST_PROTOCOL)
    print('Saved policy object')

    # save action dispatcher object
    AD_name = 'AD_' + algorithm_name
    with open(output_path + '/' + AD_name, 'wb') as output:
        pickle.dump(algorithm._action_dispatcher, output, pickle.HIGHEST_PROTOCOL)
    print('Saved Action Dispatcher')
    
    

    if evaluation:

        print('*** Evaluation ***')
        run_evaluation(output_path+'/'+algorithm_name, track_file_name, data_path, n_jobs, output_path,
                       'eval_'+output_name, filter_actions,
                       output_path + '/' + AD_name)

# %%
track_file_name = 'dataset'
rt_file_name = 'ref_traj'
data_path = './trajectory/'
max_iterations = 100
output_path = './model_file/'
n_jobs = 10

filter_actions = False
filt_a_outliers = False
evaluation = True

for reward_function in ['speed', 'spatial', 'temporal']:
    output_name = reward_function + '_reward_model'#'first_model'
    run_experiment(track_file_name, rt_file_name, data_path, max_iterations, output_path, 3,3,3, n_jobs, output_name, 
               reward_function, 2, filter_actions, 'rkdt', False, False, 10, filt_a_outliers, True, evaluation)
# Out:
# SPEED REWARD FUNCTION
# SARS ready
# loading policy
# pi: <trlib.policies.valuebased.Softmax object at 0x7ff70027edd8>
# Step 1
# Finding nearest actions for each state prime
# Time for action list 5.6775596141815186
# Time for action set 0.48354363441467285
# Time for sprime a mat 12.410649538040161
# Iteration 0
# fitQ 5.359355211257935
# Elapsed time 5.359355211257935
# Iteration 1
# maxQ 12.045907258987427
# fitQ 5.408914566040039
# Elapsed time 17.454821825027466
# Iteration 2
# maxQ 13.091437339782715
# fitQ 5.338975429534912
# Elapsed time 18.430412769317627
# Iteration 3
# maxQ 12.531635522842407
# fitQ 5.673698902130127
# Elapsed time 18.205334424972534
# Iteration 4
# maxQ 12.362218618392944
# fitQ 5.552037954330444
# Elapsed time 17.91425657272339
# Iteration 5
# maxQ 12.956385612487793
# fitQ 5.483731031417847
# Elapsed time 18.44011664390564
# Iteration 6
# maxQ 12.015736103057861
# fitQ 5.173650026321411
# Elapsed time 17.189386129379272
# Iteration 7
# maxQ 10.881363868713379
# fitQ 5.193310260772705
# Elapsed time 16.074674129486084
# Iteration 8
# maxQ 11.278628587722778
# fitQ 5.469686269760132
# Elapsed time 16.74831485748291
# Iteration 9
# maxQ 11.083201169967651
# fitQ 5.468452215194702
# Elapsed time 16.551653385162354
# Iteration 10
# maxQ 11.839172840118408
# fitQ 5.057561159133911
# Elapsed time 16.89673399925232
# Iteration 11
# maxQ 10.982069492340088
# fitQ 5.194072484970093
# Elapsed time 16.17614197731018
# Iteration 12
# maxQ 11.064913988113403
# fitQ 5.025364637374878
# Elapsed time 16.09027862548828
# Iteration 13
# maxQ 10.56242847442627
# fitQ 5.1191322803497314
# Elapsed time 15.681560754776001
# Iteration 14
# maxQ 10.971125364303589
# fitQ 4.981773376464844
# Elapsed time 15.952898740768433
# Iteration 15
# maxQ 10.507365226745605
# fitQ 5.306227922439575
# Elapsed time 15.81359314918518
# Iteration 16
# maxQ 10.604837656021118
# fitQ 4.981651782989502
# Elapsed time 15.58648943901062
# Iteration 17
# maxQ 11.065127849578857
# fitQ 5.35921311378479
# Elapsed time 16.424340963363647
# Iteration 18
# maxQ 11.130635261535645
# fitQ 5.319995641708374
# Elapsed time 16.45063090324402
# Iteration 19
# maxQ 11.184654712677002
# fitQ 5.396424055099487
# Elapsed time 16.58107876777649
# Iteration 20
# maxQ 11.052854299545288
# fitQ 5.203129291534424
# Elapsed time 16.255983591079712
# Iteration 21
# maxQ 11.526686668395996
# fitQ 5.459677457809448
# Elapsed time 16.986364126205444
# Iteration 22
# maxQ 10.77030086517334
# fitQ 5.05527663230896
# Elapsed time 15.8255774974823
# Iteration 23
# maxQ 10.955615282058716
# fitQ 5.592679500579834
# Elapsed time 16.54829478263855
# Iteration 24
# maxQ 10.27581787109375
# fitQ 4.988418340682983
# Elapsed time 15.264236211776733
# Iteration 25
# maxQ 10.99872350692749
# fitQ 5.323394775390625
# Elapsed time 16.322118282318115
# Iteration 26
# maxQ 10.55846118927002
# fitQ 4.88146185874939
# Elapsed time 15.43992304801941
# Iteration 27
# maxQ 11.353668928146362
# fitQ 4.897768259048462
# Elapsed time 16.251437187194824
# Iteration 28
# maxQ 10.73980450630188
# fitQ 4.834243297576904
# Elapsed time 15.574047803878784
# Iteration 29
# maxQ 10.907090425491333
# fitQ 4.881479740142822
# Elapsed time 15.788570165634155
# Iteration 30
# maxQ 10.195806741714478
# fitQ 4.861029624938965
# Elapsed time 15.056836366653442
# Iteration 31
# maxQ 11.031756162643433
# fitQ 4.939560413360596
# Elapsed time 15.971316576004028
# Iteration 32
# maxQ 10.289181232452393
# fitQ 4.883212566375732
# Elapsed time 15.172393798828125
# Iteration 33
# maxQ 10.46175217628479
# fitQ 4.979418039321899
# Elapsed time 15.44117021560669
# Iteration 34
# maxQ 10.247392177581787
# fitQ 4.992213010787964
# Elapsed time 15.239605188369751
# Iteration 35
# maxQ 10.635173320770264
# fitQ 4.8475341796875
# Elapsed time 15.482707500457764
# Iteration 36
# maxQ 10.72719407081604
# fitQ 5.234959840774536
# Elapsed time 15.962153911590576
# Iteration 37
# maxQ 10.483161211013794
# fitQ 4.928000450134277
# Elapsed time 15.411161661148071
# Iteration 38
# maxQ 11.051027536392212
# fitQ 5.1419837474823
# Elapsed time 16.19301128387451
# Iteration 39
# maxQ 10.423295974731445
# fitQ 5.06534218788147
# Elapsed time 15.488638162612915
# Iteration 40
# maxQ 11.11725640296936
# fitQ 5.185030937194824
# Elapsed time 16.302287340164185
# Iteration 41
# maxQ 10.563737392425537
# fitQ 5.024658203125
# Elapsed time 15.588395595550537
# Iteration 42
# maxQ 11.035196542739868
# fitQ 5.091146230697632
# Elapsed time 16.1263427734375
# Iteration 43
# maxQ 10.987468719482422
# fitQ 4.946783781051636
# Elapsed time 15.934252500534058
# Iteration 44
# maxQ 10.90125584602356
# fitQ 5.255900621414185
# Elapsed time 16.157156467437744
# Iteration 45
# maxQ 10.817753314971924
# fitQ 4.894009590148926
# Elapsed time 15.71176290512085
# Iteration 46
# maxQ 10.390637874603271
# fitQ 5.317353248596191
# Elapsed time 15.707991123199463
# Iteration 47
# maxQ 11.234192848205566
# fitQ 4.748064994812012
# Elapsed time 15.982257843017578
# Iteration 48
# maxQ 10.241841554641724
# fitQ 5.2771711349487305
# Elapsed time 15.519012689590454
# Iteration 49
# maxQ 11.211522340774536
# fitQ 5.1761698722839355
# Elapsed time 16.38769221305847
# Iteration 50
# maxQ 11.204967021942139
# fitQ 4.920702695846558
# Elapsed time 16.125669717788696
# Iteration 51
# maxQ 11.32294249534607
# fitQ 5.080654859542847
# Elapsed time 16.403597354888916
# Iteration 52
# maxQ 10.396585941314697
# fitQ 5.0352911949157715
# Elapsed time 15.431877136230469
# Iteration 53
# maxQ 10.362957954406738
# fitQ 4.793532848358154
# Elapsed time 15.156490802764893
# Iteration 54
# maxQ 11.12156891822815
# fitQ 5.287115097045898
# Elapsed time 16.408684015274048
# Iteration 55
# maxQ 11.15391230583191
# fitQ 4.920735597610474
# Elapsed time 16.074647903442383
# Iteration 56
# maxQ 10.291125059127808
# fitQ 4.968988656997681
# Elapsed time 15.260113716125488
# Iteration 57
# maxQ 10.958372354507446
# fitQ 5.053759813308716
# Elapsed time 16.012132167816162
# Iteration 58
# maxQ 10.705598592758179
# fitQ 5.087022066116333
# Elapsed time 15.792620658874512
# Iteration 59
# maxQ 10.646035194396973
# fitQ 4.7358174324035645
# Elapsed time 15.381852626800537
# Iteration 60
# maxQ 10.273260831832886
# fitQ 5.149091005325317
# Elapsed time 15.422351837158203
# Iteration 61
# maxQ 11.21110486984253
# fitQ 5.641266345977783
# Elapsed time 16.852371215820312
# Iteration 62
# maxQ 10.70814037322998
# fitQ 4.9157140254974365
# Elapsed time 15.623854398727417
# Iteration 63
# maxQ 10.373408794403076
# fitQ 4.9177405834198
# Elapsed time 15.291149377822876
# Iteration 64
# maxQ 9.885860919952393
# fitQ 4.687651872634888
# Elapsed time 14.57351279258728
# Iteration 65
# maxQ 10.53190803527832
# fitQ 4.641641616821289
# Elapsed time 15.17354965209961
# Iteration 66
# maxQ 9.793799877166748
# fitQ 4.6666717529296875
# Elapsed time 14.460471630096436
# Iteration 67
# maxQ 10.393247127532959
# fitQ 4.460272550582886
# Elapsed time 14.853519678115845
# Iteration 68
# maxQ 10.399887800216675
# fitQ 4.7458882331848145
# Elapsed time 15.14577603340149
# Iteration 69
# maxQ 10.406416654586792
# fitQ 5.119194507598877
# Elapsed time 15.525611162185669
# Iteration 70
# maxQ 10.505411624908447
# fitQ 4.901098251342773
# Elapsed time 15.40650987625122
# Iteration 71
# maxQ 10.472185850143433
# fitQ 4.865494728088379
# Elapsed time 15.337680578231812
# Iteration 72
# maxQ 10.819337606430054
# fitQ 4.816848516464233
# Elapsed time 15.636186122894287
# Iteration 73
# maxQ 10.184175729751587
# fitQ 4.578998565673828
# Elapsed time 14.763174295425415
# Iteration 74
# maxQ 9.63777780532837
# fitQ 4.76444935798645
# Elapsed time 14.40222716331482
# Iteration 75
# maxQ 9.734142303466797
# fitQ 4.7426934242248535
# Elapsed time 14.47683572769165
# Iteration 76
# maxQ 9.742255926132202
# fitQ 5.050262928009033
# Elapsed time 14.792518854141235
# Iteration 77
# maxQ 10.811439037322998
# fitQ 4.847426176071167
# Elapsed time 15.658865213394165
# Iteration 78
# maxQ 10.652334213256836
# fitQ 5.080094814300537
# Elapsed time 15.732429027557373
# Iteration 79
# maxQ 10.530699491500854
# fitQ 4.933128118515015
# Elapsed time 15.46382761001587
# Iteration 80
# maxQ 10.350613355636597
# fitQ 4.99437689781189
# Elapsed time 15.344990253448486
# Iteration 81
# maxQ 10.6141939163208
# fitQ 4.781938314437866
# Elapsed time 15.396132230758667
# Iteration 82
# maxQ 10.553624629974365
# fitQ 4.688330411911011
# Elapsed time 15.241955041885376
# Iteration 83
# maxQ 10.81499981880188
# fitQ 4.92113471031189
# Elapsed time 15.73613452911377
# Iteration 84
# maxQ 10.289557218551636
# fitQ 4.799705266952515
# Elapsed time 15.08926248550415
# Iteration 85
# maxQ 10.222079277038574
# fitQ 4.805041074752808
# Elapsed time 15.027120351791382
# Iteration 86
# maxQ 10.287330389022827
# fitQ 5.026766300201416
# Elapsed time 15.314096689224243
# Iteration 87
# maxQ 10.032391548156738
# fitQ 4.7550201416015625
# Elapsed time 14.7874116897583
# Iteration 88
# maxQ 10.172150135040283
# fitQ 4.869352340698242
# Elapsed time 15.041502475738525
# Iteration 89
# maxQ 10.192524433135986
# fitQ 4.986457586288452
# Elapsed time 15.178982019424438
# Iteration 90
# maxQ 10.111929655075073
# fitQ 4.771919012069702
# Elapsed time 14.883848667144775
# Iteration 91
# maxQ 10.394980669021606
# fitQ 4.752052545547485
# Elapsed time 15.147033214569092
# Iteration 92
# maxQ 10.55277967453003
# fitQ 5.161503076553345
# Elapsed time 15.714282751083374
# Iteration 93
# maxQ 10.248588562011719
# fitQ 4.689722299575806
# Elapsed time 14.938310861587524
# Iteration 94
# maxQ 10.680197954177856
# fitQ 5.08965277671814
# Elapsed time 15.769850730895996
# Iteration 95
# maxQ 10.814886093139648
# fitQ 4.9075846672058105
# Elapsed time 15.722470760345459
# Iteration 96
# maxQ 10.423030376434326
# fitQ 4.826903820037842
# Elapsed time 15.249934196472168
# Iteration 97
# maxQ 10.079595804214478
# fitQ 4.794272184371948
# Elapsed time 14.873867988586426
# Iteration 98
# maxQ 10.430598497390747
# fitQ 4.919341564178467
# Elapsed time 15.349940061569214
# Iteration 99
# maxQ 9.326133966445923
# fitQ 4.585054159164429
# Elapsed time 13.911188125610352
# Total elapsed time: 1565.473195552826
# Mean elapsed time: 15.65473195552826
# Std elapsed time: 1.3121543692232862
# Saved algorithm object
# Saved policy object
# Saved Action Dispatcher
# *** Evaluation ***
# Processing 1.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 2.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 3.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 4.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 5.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 6.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 7.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 8.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 9.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 10.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 11.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 12.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 13.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 14.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 15.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 16.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 17.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 18.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 19.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 20.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 21.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 22.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 23.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 24.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 25.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 26.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 27.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 28.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 29.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 30.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 31.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 32.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 33.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 34.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 35.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 36.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 37.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 38.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 39.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 40.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 41.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 42.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 43.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 44.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 45.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 46.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 47.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 48.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 49.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 50.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 51.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 52.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 53.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 54.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 55.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 56.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 57.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 58.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 59.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 60.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 61.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 62.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 63.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 64.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 65.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 66.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 67.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 68.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 69.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 70.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 71.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 72.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 73.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 74.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 75.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 76.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 77.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 78.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 79.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 80.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 81.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 82.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 83.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 84.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 85.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 86.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 87.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 88.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 89.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 90.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 91.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 92.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 93.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 94.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 95.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 96.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 97.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 98.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 99.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 100.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 101.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 102.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 103.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 104.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 105.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 106.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 107.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 108.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 109.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 110.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 111.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 112.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 113.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 114.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 115.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 116.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 117.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 118.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 119.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 120.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 121.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 122.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 123.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 124.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 125.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 126.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 127.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 128.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 129.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 130.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 131.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 132.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 133.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 134.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 135.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 136.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 137.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 138.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 139.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 140.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 141.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 142.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 143.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 144.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 145.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 146.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 147.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 148.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 149.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 150.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 151.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 152.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 153.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 154.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 155.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 156.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 157.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 158.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 159.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 160.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 161.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 162.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 163.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 164.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 165.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 166.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 167.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 168.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Processing 169.0 of 169
# Computed pilot Q values
# Computing policy Q values
# Saving results
# Saved evaluation
# SPATIAL REWARD FUNCTION
# SARS ready
# loading policy
# pi: <trlib.policies.valuebased.Softmax object at 0x7ff6ca485278>
# Step 1
# Finding nearest actions for each state prime
# Time for action list 4.774927139282227
# Time for action set 0.6806461811065674
# Time for sprime a mat 12.733028173446655
# Iteration 0
# fitQ 4.9614362716674805
# Elapsed time 4.9614362716674805
# Iteration 1
# maxQ 10.716649770736694
# fitQ 5.206921100616455
# Elapsed time 15.92357087135315
# Iteration 2
# maxQ 10.892439365386963
# fitQ 5.288583040237427
# Elapsed time 16.18102240562439
# Iteration 3
# maxQ 10.409525871276855
# fitQ 4.953757286071777
# Elapsed time 15.363283157348633
# Iteration 4
# maxQ 10.211519956588745
# fitQ 4.804682493209839
# Elapsed time 15.016202449798584
# Iteration 5
# maxQ 9.723855018615723
# fitQ 4.853796720504761
# Elapsed time 14.577651739120483
# Iteration 6
# maxQ 10.24224328994751
# fitQ 5.168405771255493
# Elapsed time 15.410649061203003
# Iteration 7
# maxQ 10.31421422958374
# fitQ 5.265130519866943
# Elapsed time 15.579344749450684
# Iteration 8
# maxQ 10.636898517608643
# fitQ 4.988654851913452
# Elapsed time 15.625553369522095
# Iteration 9
# maxQ 10.105250120162964
# fitQ 4.685933351516724
# Elapsed time 14.791183471679688
# Iteration 10
# maxQ 9.553637981414795
# fitQ 4.774143934249878
# Elapsed time 14.327781915664673
# Iteration 11
# maxQ 9.880236148834229
# fitQ 4.908296346664429
# Elapsed time 14.788532495498657
# Iteration 12
# maxQ 10.39669156074524
# fitQ 5.153400897979736
# Elapsed time 15.550092458724976
# Iteration 13
# maxQ 10.950739860534668
# fitQ 4.93514609336853
# Elapsed time 15.885885953903198
# Iteration 14
# maxQ 10.367183923721313
# fitQ 5.087188005447388
# Elapsed time 15.454371929168701
# Iteration 15
# maxQ 10.457659721374512
# fitQ 4.931784152984619
# Elapsed time 15.38944387435913
# Iteration 16
# maxQ 10.17223858833313
# fitQ 5.053746700286865
# Elapsed time 15.225985288619995
# Iteration 17
# maxQ 10.168418884277344
# fitQ 4.264361381530762
# Elapsed time 14.432780265808105
# Iteration 18
# maxQ 10.300039768218994
# fitQ 4.771687269210815
# Elapsed time 15.07172703742981
# Iteration 19
# maxQ 9.961322546005249
# fitQ 4.932195425033569
# Elapsed time 14.893517971038818
# Iteration 20
# maxQ 10.193560600280762
# fitQ 5.016131162643433
# Elapsed time 15.209691762924194
# Iteration 21
# maxQ 10.497854232788086
# fitQ 4.843825578689575
# Elapsed time 15.341679811477661
# Iteration 22
# maxQ 9.767483711242676
# fitQ 4.754658460617065
# Elapsed time 14.522142171859741
# Iteration 23
# maxQ 10.425040245056152
# fitQ 5.287505149841309
# Elapsed time 15.712545394897461
# Iteration 24
# maxQ 10.57816481590271
# fitQ 5.048325777053833
# Elapsed time 15.626490592956543
# Iteration 25
# maxQ 10.536306858062744
# fitQ 4.8851752281188965
# Elapsed time 15.42148208618164
# Iteration 26
# maxQ 9.884007692337036
# fitQ 4.925749778747559
# Elapsed time 14.809757471084595
# Iteration 27
# maxQ 10.100929260253906
# fitQ 4.793421745300293
# Elapsed time 14.8943510055542
# Iteration 28
# maxQ 10.745954036712646
# fitQ 5.148773670196533
# Elapsed time 15.89472770690918
# Iteration 29
# maxQ 10.635509729385376
# fitQ 5.093069553375244
# Elapsed time 15.72857928276062
# Iteration 30
# maxQ 10.416970014572144
# fitQ 4.814580917358398
# Elapsed time 15.231550931930542
# Iteration 31
# maxQ 9.918670892715454
# fitQ 4.725611209869385
# Elapsed time 14.644282102584839
# Iteration 32
# maxQ 10.60941481590271
# fitQ 4.78996467590332
# Elapsed time 15.39937949180603
# Iteration 33
# maxQ 10.335052013397217
# fitQ 4.992138385772705
# Elapsed time 15.327190399169922
# Iteration 34
# maxQ 10.481157302856445
# fitQ 5.216170787811279
# Elapsed time 15.697328090667725
# Iteration 35
# maxQ 10.603423833847046
# fitQ 4.90121054649353
# Elapsed time 15.504634380340576
# Iteration 36
# maxQ 10.469187498092651
# fitQ 5.1689229011535645
# Elapsed time 15.638110399246216
# Iteration 37
# maxQ 10.641410112380981
# fitQ 5.050848484039307
# Elapsed time 15.692258596420288
# Iteration 38
# maxQ 10.330050945281982
# fitQ 5.087695598602295
# Elapsed time 15.417746543884277
# Iteration 39
# maxQ 10.831689357757568
# fitQ 4.733779668807983
# Elapsed time 15.565469026565552
# Iteration 40
# maxQ 10.192427396774292
# fitQ 4.695165157318115
# Elapsed time 14.887592554092407
# Iteration 41
# maxQ 10.552069664001465
# fitQ 4.8891541957855225
# Elapsed time 15.441223859786987
# Iteration 42
# maxQ 10.165973901748657
# fitQ 4.651571750640869
# Elapsed time 14.817545652389526
# Iteration 43
# maxQ 10.611306428909302
# fitQ 5.114184617996216
# Elapsed time 15.725491046905518
# Iteration 44
# maxQ 10.32941484451294
# fitQ 5.198753118515015
# Elapsed time 15.528167963027954
# Iteration 45
# maxQ 11.39718246459961
# fitQ 5.120882987976074
# Elapsed time 16.518065452575684
# Iteration 46
# maxQ 10.520961046218872
# fitQ 4.943649768829346
# Elapsed time 15.464610815048218
# Iteration 47
# maxQ 10.470926523208618
# fitQ 5.012500286102295
# Elapsed time 15.483426809310913
# Iteration 48
# maxQ 9.930610179901123
# fitQ 4.443201303482056
# Elapsed time 14.373811483383179
# Iteration 49
# maxQ 9.718256950378418
# fitQ 5.087747097015381
# Elapsed time 14.806004047393799
# Iteration 50
# maxQ 9.94438624382019
# fitQ 4.771958112716675
# Elapsed time 14.716344356536865
# Iteration 51
# maxQ 10.910303354263306
# fitQ 5.1431074142456055
# Elapsed time 16.05341076850891
# Iteration 52
# maxQ 10.372254610061646
# fitQ 4.7982497215271
# Elapsed time 15.170504331588745
# Iteration 53
# maxQ 10.504860877990723
# fitQ 5.176116704940796
# Elapsed time 15.680977582931519
# Iteration 54
# maxQ 10.247665405273438
# fitQ 4.721369028091431
# Elapsed time 14.969034433364868
# Iteration 55
# maxQ 10.652043581008911
# fitQ 4.655692100524902
# Elapsed time 15.307735681533813
# Iteration 56
# maxQ 9.778417348861694
# fitQ 4.912939548492432
# Elapsed time 14.691356897354126
# Iteration 57
