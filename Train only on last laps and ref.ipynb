# %%
import sys
import os
import pickle
import argparse
import pandas as pd
from sklearn.ensemble.forest import ExtraTreesRegressor

from fqi.et_tuning import run_tuning
from fqi.reward_function import *
from fqi.sars_creator import to_SARS
from fqi.utils import *

from trlib.policies.valuebased import ValueBased, EpsilonGreedy, Softmax
from trlib.policies.qfunction import ZeroQ
from trlib.algorithms.reinforcement.fqi_driver import FQIDriver, DoubleFQIDriver
from trlib.environments.trackEnv import TrackEnv
from trlib.utilities.ActionDispatcher import *

# %%
track_file_name = 'dataset_offroad'
rt_file_name = 'ref_traj'
data_path = './trajectory/'

# %%
simulations = pd.read_csv(os.path.join(data_path, track_file_name + '.csv'),
                              dtype={'isReference': bool, 'is_partial':bool})
ref_tr = pd.read_csv(os.path.join(data_path, rt_file_name + '.csv'))

# %%
n_laps = simulations.tail(1).NLap.values.item(0)
simulations = simulations[(simulations.NLap == 17) | (simulations.NLap >= n_laps - 1000)]
# Out:
#        NLap       time  isReference  is_partial   xCarWorld    yCarWorld  \
# 11893  17.0   0.055996         True       False  632.738159  1167.866089
# 11894  17.0   0.155996         True       False  641.394775  1168.036987
# 11895  17.0   0.255996         True       False  650.064575  1168.186279
# 11896  17.0   0.355996         True       False  658.747070  1168.332764
# 11897  17.0   0.455996         True       False  667.441956  1168.479248
# 11898  17.0   0.555996         True       False  676.149048  1168.625732
# 11899  17.0   0.655996         True       False  684.868042  1168.772217
# 11900  17.0   0.755996         True       False  693.598755  1168.918701
# 11901  17.0   0.855996         True       False  702.340820  1169.065186
# 11902  17.0   0.955996         True       False  711.094299  1169.211670
# 11903  17.0   1.055996         True       False  719.858643  1169.358154
# 11904  17.0   1.155996         True       False  728.633728  1169.504639
# 11905  17.0   1.255996         True       False  737.419128  1169.651123
# 11906  17.0   1.355996         True       False  746.214905  1169.797607
# 11907  17.0   1.455996         True       False  755.020508  1169.944092
# 11908  17.0   1.555996         True       False  763.835815  1170.090576
# 11909  17.0   1.655996         True       False  772.660461  1170.237061
# 11910  17.0   1.755996         True       False  781.494263  1170.383545
# 11911  17.0   1.855996         True       False  790.336975  1170.530029
# 11912  17.0   1.955996         True       False  799.188293  1170.676514
# 11913  17.0   2.055996         True       False  808.048035  1170.822998
# 11914  17.0   2.155996         True       False  816.916138  1170.965210
# 11915  17.0   2.255996         True       False  825.792175  1171.105591
# 11916  17.0   2.355996         True       False  834.675964  1171.245972
# 11917  17.0   2.455996         True       False  843.567444  1171.383545
# 11918  17.0   2.555996         True       False  852.466492  1171.511230
# 11919  17.0   2.655996         True       False  861.373047  1171.620728
# 11920  17.0   2.755996         True       False  870.286926  1171.709839
# 11921  17.0   2.855996         True       False  879.207825  1171.778198
# 11922  17.0   2.955996         True       False  888.135620  1171.825073
# ...     ...        ...          ...         ...         ...          ...
# 12583  17.0  69.055996         True       False  377.128876  1162.515503
# 12584  17.0  69.155996         True       False  385.370331  1162.954956
# 12585  17.0  69.255996         True       False  393.639954  1163.332031
# 12586  17.0  69.355996         True       False  401.936737  1163.647827
# 12587  17.0  69.455996         True       False  410.259644  1163.912964
# 12588  17.0  69.555996         True       False  418.607178  1164.150757
# 12595     0.000000      0.0             1.0
# 12596     0.000000      0.0             1.0
# 12597     0.000000      0.0             1.0
# 12598     0.000000      0.0             1.0
# 12599     0.000000      0.0             1.0
# 12600     0.000000      0.0             1.0
# 12601     0.000000      0.0             1.0
# 12602     0.000000      0.0             1.0
# 12603     0.000000      0.0             1.0
# 12604     0.000000      0.0             1.0
# 12605     0.000000      0.0             1.0
# 12606    -0.002744      0.0             1.0
# 12607    -0.003848      0.0             1.0
# 12608    -0.004131      0.0             1.0
# 12609    -0.005638      0.0             1.0
# 12610    -0.012017      0.0             1.0
# 12611    -0.015695      0.0             1.0
# 12612    -0.015314      0.0             1.0
#
# [720 rows x 33 columns]

# %%
right_laps = np.array([ 1.,  8.,  9., 11., 14., 16., 17., 20., 45., 46., 49.,  59., 62.])
penalty = LikelihoodPenalty(bandwidth = 1, kernel = 'gaussian')
penalty.fit(simulations[simulations.NLap.isin(right_laps)][penalty_cols].values, 10)

# %%
rf = Temporal_projection(ref_tr, penalty=penalty, clip_range=(-np.inf, np.inf))
dataset = to_SARS(simulations, rf)

# %%
nmin = 1

# Create environment
state_dim = len(state_cols)
action_dim = len(action_cols)
mdp = TrackEnv(state_dim, action_dim, 0.99999, 'continuous')

# Parameters of ET regressor
regressor_params = {'n_estimators': 100,
                    'criterion': 'mse',
                    'min_samples_split': 2,
                    'min_samples_leaf': nmin,
                    'n_jobs': 10,
                    'random_state': 42}
regressor = ExtraTreesRegressor

# %%
pi = ValueBased([], ZeroQ())

# %%
cols = ['t'] + state_cols + action_cols + ['r'] + state_prime_cols + ['absorbing']
# Define the masks used by the action dispatcher
state_mask = [i for i, s in enumerate(state_cols) if s in knn_state_cols]
data_mask = [i for i, c in enumerate(cols) if c in knn_state_cols]

# %%
action_dispatcher = RadialKDTActionDispatcher
alg_actions = dataset[action_cols].values

# %%
fqi = DoubleFQIDriver

# %%
algorithm = fqi(mdp=mdp,
                    policy=pi,
                    actions=alg_actions,
                    max_iterations=100,
                    regressor_type=regressor,
                    data=dataset[cols].values,
                    action_dispatcher=action_dispatcher,
                    state_mask=state_mask,
                    data_mask=data_mask,
                    s_norm=False,
                    filter_a_outliers=False,
                    ad_n_jobs=10,
                    ad_param=10,
                    verbose=True,
                    **regressor_params)

# %%
algorithm.step()
# Out:
# Step 1
# Finding nearest actions for each state prime
# Time for action list 0.01907205581665039
# Time for action set 0.007899761199951172
# Time for sprime a mat 0.021032333374023438
# Iteration 0
# fitQ 0.26702094078063965
# Elapsed time 0.26702094078063965
# Iteration 1
# maxQ 0.4305572509765625
# fitQ 0.39272427558898926
# Elapsed time 0.8232815265655518
# Iteration 2
# maxQ 0.45353078842163086
# fitQ 0.33298754692077637
# Elapsed time 0.7865183353424072
# Iteration 3
# maxQ 0.4490773677825928
# fitQ 0.3931453227996826
# Elapsed time 0.8422226905822754
# Iteration 4
# maxQ 0.4480905532836914
# fitQ 0.39978790283203125
# Elapsed time 0.8478784561157227
# Iteration 5
# maxQ 0.46179914474487305
# fitQ 0.4234282970428467
# Elapsed time 0.8852274417877197
# Iteration 6
# maxQ 0.4478750228881836
# fitQ 0.3959217071533203
# Elapsed time 0.8437967300415039
# Iteration 7
# maxQ 0.5544466972351074
# fitQ 0.5538663864135742
# Elapsed time 1.1083130836486816
# Iteration 8
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-54-2222de38af48> in <module>
# ----> 1 algorithm.step()
#
# ~/baRricheLlo/trlib/algorithms/algorithm.py in step(self, callbacks, **kwargs)
#      44         self._result.add_step(step=self._step)
#      45
# ---> 46         self._step_core(**kwargs)
#      47
#      48         for cb in callbacks:
#
# ~/baRricheLlo/trlib/algorithms/reinforcement/fqi_driver.py in _step_core(self, **kwargs)
#     444         fit_time_list = []
#     445         for i in range(self._max_iterations):
# --> 446             maxq_time, fit_time = self._iter(sa, r, s_prime, absorbing, **kwargs)
#     447
#     448             maxq_time_list = maxq_time_list + [maxq_time]
#
# ~/baRricheLlo/trlib/algorithms/reinforcement/fqi_driver.py in _iter(self, sa, r, s_prime, absorbing, **fit_params)
#     386                 # Find the best action
#     387                 _, maxa_A = self._policy.Q.max_sa(self.sprime_a_A, self.n_actions_per_state_prime_A, absorbing_A, 0)
# --> 388                 _, maxa_B = self._policy.Q.max_sa(self.sprime_a_B, self.n_actions_per_state_prime_B, absorbing_B, 1)
#     389
#     390                 # Get the value of the action using the other Q
#
# ~/baRricheLlo/trlib/policies/double_qfunction.py in max_sa(self, sa, n_actions_per_state, absorbing, q_id)
#     159
#     160         # compute Q values for each state action pair
# --> 161         vals = self.values(sa, q_id)
#     162
#     163         n_states = len(n_actions_per_state)
#
# ~/baRricheLlo/trlib/policies/double_qfunction.py in values(self, sa, q_id)
#      42             return Q
#      43         else:
# ---> 44             return self._regressor[q_id].predict(sa)
#      45
#      46     def max(self, states, actions=None, absorbing=None, q_id=None):
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py in predict(self, X)
#     707                  **_joblib_parallel_args(require="sharedmem"))(
#     708             delayed(_accumulate_prediction)(e.predict, X, [y_hat], lock)
# --> 709             for e in self.estimators_)
#     710
#     711         y_hat /= len(self.estimators_)
#
# ~/anaconda3/lib/python3.7/site-packages/joblib/parallel.py in __call__(self, iterable)
#     919             # remaining jobs.
#     920             self._iterating = False
# --> 921             if self.dispatch_one_batch(iterator):
#     922                 self._iterating = self._original_iterator is not None
#     923
#
# ~/anaconda3/lib/python3.7/site-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     757                 return False
#     758             else:
# --> 759                 self._dispatch(tasks)
#     760                 return True
#     761
#
# ~/anaconda3/lib/python3.7/site-packages/joblib/parallel.py in _dispatch(self, batch)
#     714         with self._lock:
#     715             job_idx = len(self._jobs)
# --> 716             job = self._backend.apply_async(batch, callback=cb)
#     717             # A job can complete so quickly than its callback is
#     718             # called before we get here, causing self._jobs to
#
# ~/anaconda3/lib/python3.7/site-packages/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     224     def apply_async(self, func, callback=None):
#     225         """Schedule a func to be run"""
# --> 226         return self._get_pool().apply_async(
#     227             SafeFunction(func), callback=callback)
#     228
#
# ~/anaconda3/lib/python3.7/site-packages/joblib/_parallel_backends.py in _get_pool(self)
#     365         """
#     366         if self._pool is None:
# --> 367             self._pool = ThreadPool(self._n_jobs)
#     368         return self._pool
#     369
#
# ~/anaconda3/lib/python3.7/multiprocessing/pool.py in __init__(self, processes, initializer, initargs)
#     800
#     801     def __init__(self, processes=None, initializer=None, initargs=()):
# --> 802         Pool.__init__(self, processes, initializer, initargs)
#     803
#     804     def _setup_queues(self):
#
# ~/anaconda3/lib/python3.7/multiprocessing/pool.py in __init__(self, processes, initializer, initargs, maxtasksperchild, context)
#     174         self._processes = processes
#     175         self._pool = []
# --> 176         self._repopulate_pool()
#     177
#     178         self._worker_handler = threading.Thread(
#
# ~/anaconda3/lib/python3.7/multiprocessing/pool.py in _repopulate_pool(self)
#     239             w.name = w.name.replace('Process', 'PoolWorker')
#     240             w.daemon = True
# --> 241             w.start()
#     242             util.debug('added worker')
#     243
#
# ~/anaconda3/lib/python3.7/multiprocessing/dummy/__init__.py in start(self)
#      49         if hasattr(self._parent, '_children'):
#      50             self._parent._children[self] = None
# ---> 51         threading.Thread.start(self)
#      52
#      53     @property
#
# ~/anaconda3/lib/python3.7/threading.py in start(self)
#     850                 del _limbo[self]
#     851             raise
# --> 852         self._started.wait()
#     853
#     854     def run(self):
#
# ~/anaconda3/lib/python3.7/threading.py in wait(self, timeout)
#     550             signaled = self._flag
#     551             if not signaled:
# --> 552                 signaled = self._cond.wait(timeout)
#     553             return signaled
#     554
#
# ~/anaconda3/lib/python3.7/threading.py in wait(self, timeout)
#     294         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     295             if timeout is None:
# --> 296                 waiter.acquire()
#     297                 gotit = True
#     298             else:
#
# KeyboardInterrupt:
